# %%
import sqlite3
from sqlite3 import OperationalError
import os
from urllib.request import urlopen
import json
import time
import pandas as pd
import pandas.io.sql
#change directory
os.chdir('C:\\Users\\Jason\\Documents\\Depaul\\ITF Competition\\Raw Data')

# %%
#Import Excel file into a DataFrame
#For more info http://pandas-docs.github.io/pandas-docs-travis/io.html#io-excel
xls_file=pd.ExcelFile('Accountability Reports - AYP Status_Historical.xlsx')
table=xls_file.parse('Historical AYP')
#notice that the first row of the Excel file does not contain the column names
table.columns
# Out:
# Index([2004, 'Unnamed: 1', 'Unnamed: 2', 2005, 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 2006, 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 2007, 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 2008, 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 2009, 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 2010, 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 2011, 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 2012, 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 2013, 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47'], dtype='object')

# %%
pd.read_excel?

# %%
#alternative to ExcelFile class is read_excel
AYPStatus=pd.read_excel('Accountability Reports - AYP Status_Historical.xlsx','Historical AYP',header=1,skiprows=0)
AYPStatus.columns
# Out:
# Index(['RCDTS Code', 'School Name', '2004 AYP', '2004 AYP Reading', '2004 AYP Math', '2005 AYP', '2005 AYP Reading', '2005 AYP Math', '2005-2006 Federal Status', '2005-2006 State Status', '2006 AYP', '2006 AYP Reading', '2006 AYP Math', '2006-2007 Federal Status', '2006-2007 State Status', '2007 AYP', '2007 AYP Reading', '2007 AYP Math', '2007-2008 Federal Status', '2007-2008 State Status', '2008 AYP', '2008 AYP Reading', '2008 AYP Math', '2008-2009 Federal Status', '2008-2009 State Status', '2009 AYP', '2009 AYP Reading', '2009 AYP Math', '2009-2010 Federal Status', '2009-2010 State Status', '2010 AYP', '2010 AYP Reading', '2010 AYP Math', '2010-2011 Federal Status', '2010-2011 State Status', '2011 AYP', '2011 AYP Reading', '2011 AYP Math', '2011-2012 Federal Status', '2011-2012 State Status', '2012 AYP', '2012 AYP Reading', '2012 AYP Math', '2012-2013 Federal Status', '2012-2013 State Status', '2013 AYP', '2013 AYP Reading', '2013 AYP Math', '2013-2013 Federal Status', '2013-2014 S
# ...

# %%
#Example export to SQL
conn = sqlite3.connect('ChicagoPublicSchools.db')

AYPStatus.to_sql('HistoricalAYP', conn, if_exists='replace')

c = conn.cursor()
print(c.execute("SELECT * FROM HistoricalAYP;").fetchall())

c.close()
conn.close()
# Out:
# [('150162990250001', 'AMUNDSEN HIGH SCHOOL', 'No', 'No', 'No', 'No', 'No', 'No', 'Corrective Action', 'Academic Watch Status', 'No', 'No', 'No', 'Restructuring', 'Academic Watch Status', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status Year 5', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status Year 6', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status Year 7', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status Year 8', 'No', 'No', 'No', 'Restructuring Implementation', 'Academic Watch Status Year 9', 'No ', 'No ', 'No ', 'Restructuring Implementation ', 'Academic Watch Status Year 10 '), ('150162990250002', 'AUSTIN COMMUNITY HIGH SCHOOL', 'No', 'No', 'No', 'No', 'No', 'No', 'Corrective Action', 'Academic Watch Status', 'No', 'No', 'No', 'Restructuring', 'Academic Watch Status', None, None, None, None, None, None, None, N
# ...
